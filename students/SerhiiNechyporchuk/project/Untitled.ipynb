# %%
import en_core_web_lg
from nltk.tree import Tree
import pandas as pd
from stanfordcorenlp import StanfordCoreNLP

# %%
df = pd.read_csv('dataset/phrases_cleaned_1522422847595.csv', usecols=['phrase'])
df = df.sample(frac=1.0)

# %%
df['phrase'][0]
# Out:
# "Find people who wrote posts mentioning Stacy Vaughn and liked any post 9 times and clicked on ad with 'blackout' in it"

# %%
snlp = StanfordCoreNLP('http://localhost', port=9000)

# %%
Tree.fromstring(snlp.parse("Find people who wrote posts mentioning Stacy Vaughn and liked any post 9 times or clicked on ad with 'blackout' in it"))
# Out:
# Tree('ROOT', [Tree('SINV', [Tree('VP', [Tree('VBD', ['wrote'])]), Tree('NP', [Tree('NP', [Tree('NNS', ['posts'])]), Tree('VP', [Tree('VP', [Tree('VP', [Tree('VBG', ['mentioning']), Tree('NP', [Tree('NNP', ['Stacy']), Tree('NNP', ['Vaughn'])])]), Tree('CC', ['and']), Tree('VP', [Tree('VBD', ['liked']), Tree('NP', [Tree('DT', ['any']), Tree('NN', ['post'])]), Tree('NP-TMP', [Tree('CD', ['9']), Tree('NNS', ['times'])])])]), Tree('CC', ['or']), Tree('VP', [Tree('VBN', ['clicked']), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NN', ['ad'])])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('``', ['`']), Tree('NP', [Tree('NN', ['blackout'])]), Tree("''", ["'"]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('PRP', ['it'])])])])])])])])])])
